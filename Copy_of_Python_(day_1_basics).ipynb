# %% [markdown]
# <a href="https://colab.research.google.com/github/shivalikasikarwar0529-gif/Python-Learning/blob/main/Copy_of_Python_(day_1_basics).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+3
# Out:
# 5

# %% [markdown]
# example-1 of mathematic operations

# %%
8/4
# Out:
# 2.0

# %% [markdown]
# example-2 of mathematic operations

# %%
7//2
# Out:
# 3

# %% [markdown]
# Integer/Floor operation we use // sign

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# for fetching cube of any digit we can use double ashtricks

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# for fetching modulus

# %%
print('shivalika "laptop"')
# Out:
# shivalika "laptop"

# %% [markdown]
# When we use single quote in string then we use double quote to wrap the code.

# %%
print ("Shivalika's 'laptop'")
# Out:
# Shivalika's 'laptop'

# %% [markdown]
# When we use double quote in string then we use single quote to wrap the code.

# %%
print('shivalika\'s "laptop"')
# Out:
# shivalika's "laptop"

# %% [markdown]
# When we use both quote inside string then we use backslash(\) to ignore error

# %%
'shivalika' + 'shivalika'
# Out:
# 'shivalikashivalika'

# %% [markdown]
# Concetanation ke liye

# %%
4 * 'shivalika'
# Out:
# 'shivalikashivalikashivalikashivalika'

# %% [markdown]
# to repeat text we can write code like this

# %%
print ("'shivalika'\n c: docs")
# Out:
# 'shivalika'
#  c: docs

# %% [markdown]
#  \n is used to change line from cursor

# %%
print (r"c:\docs\shivalika")
# Out:
# c:\docs\shivalika

# %% [markdown]
# This r is known as raw string means no conversion of text
