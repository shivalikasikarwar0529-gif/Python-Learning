# %% [markdown]
# <a href="https://colab.research.google.com/github/shivalikasikarwar0529-gif/Python-Learning/blob/main/Day_2%2C3_(Variables%2CList).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=2
y=3

# %% [markdown]
# Variabls are like containers to put any value like here we have given 2 & 3 later we make operations with variables

# %%
x+y
# Out:
# 5

# %% [markdown]
# like this we can make different operations with variables

# %%
x=15

# %% [markdown]
# we can change its value also in numeric.

# %%
x+y
# Out:
# 18

# %% [markdown]
# Now, we can see its giving result as changed variable

# %%
name='youtube'

# %% [markdown]
# we can use variables with string also but here assigned value can't be changed

# %%
name+' songs'
# Out:
# 'youtube songs'

# %% [markdown]
# Here '+' sign is mendatory to concatenation

# %%
name[0]
# Out:
# 'y'

# %% [markdown]
# It will fetch 1st letter of value.
# #0 acts as 1 in computer numbering.
# #if we write code like "name[8]" then it will show error bcz 8th number is out of string index."

# %%
name[-1]
# Out:
# 'e'

# %% [markdown]
# Because negative numbers acts as reverse counting

# %%
name[1:4]
# Out:
# 'out'

# %% [markdown]
# 1st value = starting
# 2nd value = ending(exclusive), we can check from here 'youtube'

# %%
name[1:]
# Out:
# 'outube'

# %% [markdown]
# In this case, it'll start with 2nd letter and go till the end bcz end isn't specified.

# %%
name[:4]
# Out:
# 'yout'

# %% [markdown]
# Here, it'll start with 1st letter & end at 4th bcz end isn't specified so basically whenever we don't specify value the code will run from or till the end or beginning.

# %%
name[3:10]
# Out:
# 'tube'

# %% [markdown]
# By mistake, if we assign second value out of range still it won't give error but will return value at the last character.

# %%
'my'+name[3: ]
# Out:
# 'mytube'

# %% [markdown]
# This way we can make changes in variables.

# %%
mytube = 'shivalika'

# %%
len(mytube)
# Out:
# 9

# %% [markdown]
# like this python provides many default text/string functions

# %%
nums=[56,89,23,78,51,24,62]

# %% [markdown]
# A group of variables is known as list, so here we created a list in which we can add multiple values at a time.

# %%
nums
# Out:
# [56, 89, 23, 78, 51, 24, 62]

# %%
nums[0]
# Out:
# 56

# %% [markdown]
# Same as variable, Here too we can get specific index value.

# %%
nums[-1]
# Out:
# 62

# %% [markdown]
# Negative numbers will also act same as previous.

# %%
names = ['shivalika', 'naveen','kiran']
names
# Out:
# ['shivalika', 'naveen', 'kiran']

# %% [markdown]
# we can also add multiple strings at a time.

# %%
values=[9.5, 'shivalika', 25]
values
# Out:
# [9.5, 'shivalika', 25]

# %% [markdown]
# Like this, we can add different data in list.

# %%
mil=[nums, names]
mil
# Out:
# [[56, 89, 23, 78, 51, 24, 62], ['shivalika', 'naveen', 'kiran']]

# %% [markdown]
# we can create miscellanious list also.

# %%
nums.append(68)
nums
# Out:
# [56, 89, 23, 78, 51, 24, 62, 68, 68]

# %% [markdown]
# Here, we can use inbuilt functions too after adding (.) to variable name

# %%
nums.insert(2,82)

# %%
nums
# Out:
# [56, 89, 82, 23, 78, 51, 24, 62, 68, 68]

# %% [markdown]
# Like this we can insert any element by specifying index number

# %%
nums.remove(78)
nums
# Out:
# [56, 89, 82, 23, 51, 24, 62, 68, 68]

# %% [markdown]
# we can remove any element also

# %%
nums.pop(1)
# Out:
# 89

# %% [markdown]
# we can pull out any element by specifying index value in this fucntion.

# %%
nums.pop()
# Out:
# 68

# %% [markdown]
# By mistake, if we don't specify any index value then it won't give any error, instead it'll return last element.

# %%
del nums[4:]

# %%
nums
# Out:
# [56, 82, 23, 51]

# %% [markdown]
# It'll return 4 value rest will be deleted.

# %%
nums.extend([29,12,15,19])
nums
# Out:
# [56, 82, 23, 51, 29, 12, 15, 19]

# %% [markdown]
# Like this we can extend elements into list.

# %%
min(nums)
# Out:
# 12

# %% [markdown]
# like this we can use inbuilt functions

# %%
nums.sort()
nums
# Out:
# [12, 15, 19, 23, 29, 51, 56, 82]

# %% [markdown]
# it'll retrive values in sorted form.
