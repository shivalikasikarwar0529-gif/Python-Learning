# %% [markdown]
# <a href="https://colab.research.google.com/github/shivalikasikarwar0529-gif/Python-Learning/blob/main/Day_4(Tuple%2C_Set).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tup=(21,36,14,25)
tup
# Out:
# (21, 36, 14, 25)

# %% [markdown]
# Tuple is also a kind of List but this is immutable(No change)
# Index & Count are the only 2 inbuilt functions provided by python for tuple.

# %% [markdown]
# As tuple is immutable, equation in tuple is faster than List. Even execution speed is also enhanced here. This is mainly used for no change in value of list

# %%
tup[1]
# Out:
# 36

# %% [markdown]
# To fetch value, we use [] , to insert value we use ()

# %%
s={22,25,14,12,2,98,25}
s
# Out:
# {2, 12, 14, 22, 25, 98}

# %% [markdown]
# This is Set, apparently this is a collection of element but unique elements.
# Basic use of set is to make execusiton easy & fast, For which, Set doesn't support indexing, won't maintain sequence, won't support duplicate values.
# #This is mutable.
